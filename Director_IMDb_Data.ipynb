# %% [markdown]
# <a href="https://colab.research.google.com/github/brianhphillips/testrepo/blob/main/Director_IMDb_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# Update this path if your folder is named differently
imdb_path = "/content/drive/MyDrive/"

files = {
    'name_basics': os.path.join(imdb_path, 'name.basics.tsv'),
    'title_crew': os.path.join(imdb_path, 'title.crew.tsv'),
    'title_basics': os.path.join(imdb_path, 'title.basics.tsv'),
    'title_ratings': os.path.join(imdb_path, 'title.ratings.tsv')
}

# %%
import pandas as pd

target_directors = [
    "Kyle Balda", "Chris Buck", "Anthony Russo", "Pierre Coffin",
    "Joss Whedon", "Chris Renaud", "Joe Russo", "J.J. Abrams",
    "Jon Watts", "David Yates", "James Cameron", "Lee Unkrich"
]

# Only load the columns we need
name_df = pd.read_csv(files['name_basics'], sep='\t', usecols=['nconst', 'primaryName'], na_values='\\N', dtype=str)
directors_df = name_df[name_df['primaryName'].isin(target_directors)]

# %%
from tqdm import tqdm

def get_titles_for_directors_in_chunks(crew_path, director_ids, chunk_size=100000):
    result_rows = []
    chunks = pd.read_csv(crew_path, sep='\t', na_values='\\N', dtype=str, chunksize=chunk_size)

    for chunk in tqdm(chunks, desc="Processing title.crew.tsv"):
        chunk = chunk.dropna(subset=['directors'])
        chunk['directors'] = chunk['directors'].str.split(',')
        exploded = chunk.explode('directors')
        filtered = exploded[exploded['directors'].isin(director_ids)]
        result_rows.append(filtered[['tconst', 'directors']])

    return pd.concat(result_rows, ignore_index=True)

title_directors_df = get_titles_for_directors_in_chunks(files['title_crew'], directors_df['nconst'].tolist())
# Out:
# Processing title.crew.tsv: 0it [00:00, ?it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 1it [00:00,  1.47it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 2it [00:02,  1.55s/it]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 3it [00:04,  1.54s/it]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 4it [00:05,  1.52s/it]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 5it [00:06,  1.28s/it]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 6it [00:07,  1.12s/it]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 7it [00:08,  1.02s/it]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 8it [00:09,  1.04it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 9it [00:09,  1.31it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 10it [00:09,  1.53it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 11it [00:10,  1.71it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 12it [00:10,  1.85it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 13it [00:11,  1.76it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 14it [00:12,  1.72it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 15it [00:12,  1.90it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 16it [00:12,  1.89it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 17it [00:13,  1.76it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 18it [00:14,  1.94it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 19it [00:14,  1.90it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 20it [00:14,  2.05it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 21it [00:15,  2.29it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 22it [00:15,  2.39it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 23it [00:15,  2.70it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 24it [00:16,  2.69it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 25it [00:16,  2.68it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 26it [00:16,  2.97it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 27it [00:17,  2.78it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 28it [00:17,  3.07it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 29it [00:17,  2.80it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 30it [00:18,  2.96it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 31it [00:18,  2.58it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 32it [00:19,  2.66it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 33it [00:19,  2.05it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 34it [00:20,  1.67it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 35it [00:21,  1.69it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 36it [00:22,  1.55it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 37it [00:22,  1.41it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 38it [00:23,  1.47it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 39it [00:24,  1.40it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 40it [00:25,  1.18it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 41it [00:26,  1.25it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 42it [00:26,  1.55it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 43it [00:26,  1.69it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 44it [00:27,  1.88it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 45it [00:27,  1.87it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 46it [00:28,  1.97it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 47it [00:28,  1.97it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 48it [00:29,  2.09it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 49it [00:29,  2.35it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 50it [00:29,  2.33it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 51it [00:30,  2.40it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 52it [00:30,  2.24it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 53it [00:31,  2.09it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 54it [00:31,  2.24it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 55it [00:32,  2.05it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 56it [00:32,  2.00it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 57it [00:33,  2.00it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 58it [00:34,  1.87it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 59it [00:34,  2.02it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 60it [00:35,  1.81it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 61it [00:35,  1.71it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 62it [00:36,  1.59it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 63it [00:37,  1.49it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 64it [00:37,  1.60it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 65it [00:38,  1.51it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 66it [00:39,  1.61it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 67it [00:39,  1.53it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 68it [00:40,  1.45it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 69it [00:40,  1.70it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 70it [00:41,  1.87it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 71it [00:41,  2.22it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 72it [00:41,  2.38it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 73it [00:42,  2.61it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 74it [00:42,  2.35it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 75it [00:43,  2.24it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 76it [00:44,  1.66it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 77it [00:44,  1.86it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 78it [00:45,  1.83it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 79it [00:45,  1.99it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 80it [00:46,  2.03it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 81it [00:46,  2.24it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 82it [00:46,  2.18it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 83it [00:47,  2.32it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 84it [00:47,  2.11it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 85it [00:48,  2.30it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 86it [00:48,  2.35it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 87it [00:48,  2.65it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 88it [00:49,  2.68it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 89it [00:49,  2.60it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 90it [00:50,  2.23it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 91it [00:50,  2.19it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 92it [00:51,  1.77it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 93it [00:52,  1.78it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 94it [00:52,  1.59it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 95it [00:53,  1.61it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 96it [00:54,  1.55it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 97it [00:55,  1.38it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 98it [00:55,  1.41it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 99it [00:56,  1.40it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 100it [00:56,  1.61it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 101it [00:57,  1.64it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 102it [00:57,  1.84it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 103it [00:58,  1.85it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 104it [00:59,  1.75it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 105it [00:59,  1.86it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 106it [01:00,  1.82it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 107it [01:00,  1.77it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 108it [01:01,  1.90it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 109it [01:01,  1.83it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 110it [01:02,  1.73it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 111it [01:02,  1.89it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 112it [01:03,  1.84it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 113it [01:03,  1.77it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 114it [01:04,  1.87it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 115it [01:04,  1.93it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 116it [01:05,  1.97it/s]/tmp/ipython-input-1715068275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['directors'] = chunk['directors'].str.split(',')
# Processing title.crew.tsv: 117it [01:05,  1.79it/s]

# %%
def get_movies_by_ids(basics_path, tconst_list, chunk_size=100000):
    matched = []
    chunks = pd.read_csv(basics_path, sep='\t', usecols=['tconst', 'titleType'], na_values='\\N', dtype=str, chunksize=chunk_size)

    for chunk in tqdm(chunks, desc="Filtering title.basics.tsv"):
        movies = chunk[chunk['titleType'] == 'movie']
        filtered = movies[movies['tconst'].isin(tconst_list)]
        matched.append(filtered)

    return pd.concat(matched, ignore_index=True)

movie_titles_df = get_movies_by_ids(files['title_basics'], title_directors_df['tconst'].unique().tolist())
# Out:
# Filtering title.basics.tsv: 117it [00:39,  2.95it/s]

# %%
ratings_df = pd.read_csv(files['title_ratings'], sep='\t', na_values='\\N', dtype={'tconst': str, 'averageRating': float, 'numVotes': int})

# Join: keep only rated movies directed by our targets
merged = title_directors_df.merge(directors_df, left_on='directors', right_on='nconst') \
                           .merge(movie_titles_df, on='tconst') \
                           .merge(ratings_df, on='tconst')

# %%
# Average IMDb rating per director
average_ratings = merged.groupby('primaryName')['averageRating'].mean().reset_index()
average_ratings = average_ratings.sort_values(by='averageRating', ascending=False)

print(average_ratings)
# Out:
#       primaryName  averageRating
# 10    Lee Unkrich       8.180000
# 8     Joss Whedon       7.525000
# 5   James Cameron       7.281818
# 7       Jon Watts       7.137500
# 3     David Yates       7.063636
# 4     J.J. Abrams       6.942857
# 0   Anthony Russo       6.760000
# 11  Pierre Coffin       6.750000
# 2    Chris Renaud       6.614286
# 6       Joe Russo       6.500000
# 9      Kyle Balda       6.400000
# 1      Chris Buck       6.100000
