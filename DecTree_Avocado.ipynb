# %% [markdown]
# <a href="https://colab.research.google.com/github/brianhphillips/testrepo/blob/main/DecTree_Avocado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import libraries
import kagglehub
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# %%
# Step 2: Download the dataset
path = kagglehub.dataset_download("amldvvs/avocado-ripeness-classification-dataset")
print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/amldvvs/avocado-ripeness-classification-dataset?dataset_version_number=1...
# 100%|██████████| 3.64k/3.64k [00:00<00:00, 5.45MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/amldvvs/avocado-ripeness-classification-dataset/versions/1

# %%
# Step 3: Load dataset
data_path = f"{path}/avocado_ripeness_dataset.csv"
df = pd.read_csv(data_path)

# %%
# Step 4: Split features and target
X = df.drop('ripeness', axis=1)
y = df['ripeness']

# %%
# Step 5: Handle categorical features using one-hot encoding
# Identify object type columns which are likely categorical strings
categorical_cols = X.select_dtypes(include='object').columns
# Apply one-hot encoding to these columns
X_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=True) # drop_first avoids multicollinearity

# %%
# Step 6: Split into train and test (optional for visualization)
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
# Step 7: Train Decision Tree
clf = DecisionTreeClassifier(max_depth=4, random_state=42)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %%
# Step 8: Visualize the tree
plt.figure(figsize=(20, 10))
# Use the column names from X_encoded as feature names
plot_tree(clf, feature_names=X_encoded.columns, class_names=clf.classes_, filled=True, rounded=True)
plt.title("Avocado Ripeness Decision Tree (max_depth=4)")
plt.show()
